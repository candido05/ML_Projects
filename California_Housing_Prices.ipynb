# %% [markdown]
# <a href="https://colab.research.google.com/github/candido05/ML_Projects/blob/main/California_Housing_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Projetos/California Housing Prices/housing.csv")
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
data_train = X_train.join(y_train)
data_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3637     -118.44     34.23                36.0       1730.0           387.0
# 19727    -121.47     38.95                34.0       2129.0           350.0
# 9079     -118.28     34.76                19.0       3430.0           601.0
# 18568    -121.75     36.92                48.0       1801.0           353.0
# 10445    -117.60     33.43                21.0       3951.0           562.0
# ...          ...       ...                 ...          ...             ...
# 2150     -119.78     36.77                45.0       1315.0           256.0
# 15898    -122.39     37.72                52.0        135.0            34.0
# 5552     -118.38     33.95                29.0       1821.0           588.0
# 17457    -120.44     34.68                 6.0       2187.0           277.0
# 9414     -122.49     37.86                35.0       2729.0           538.0
#
#        population  households  median_income ocean_proximity  \
# 3637       1099.0       353.0         4.0368       <1H OCEAN
# 19727       969.0       314.0         2.7039          INLAND
# 9079       1817.0       571.0         4.7875          INLAND
# 18568      1071.0       361.0         3.6000       <1H OCEAN
# 10445      1392.0       543.0         5.1439      NEAR OCEAN
# ...           ...         ...            ...             ...
# 2150        666.0       240.0         2.3562          INLAND
# 15898        93.0        26.0         2.1484        NEAR BAY
# 5552       1397.0       523.0         2.5833       <1H OCEAN
# 17457       697.0       273.0         6.2685      NEAR OCEAN
# 9414        969.0       528.0         6.7669        NEAR BAY
#
#        median_house_value
# 3637             183100.0
# 19727            106300.0
# 9079             163600.0
# 18568            194500.0
# 10445            414000.0
# ...                   ...
# 2150              58100.0
# 15898            181300.0
# 5552             187500.0
# 17457            307400.0
# 9414             500001.0
#
# [16346 rows x 10 columns]

# %%
data_train.hist(figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
data_train.corr()
# Out:
# <ipython-input-37-e6bb2ed549f3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_train.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925828           -0.106397     0.048037
# latitude            -0.925828  1.000000            0.010724    -0.039724
# housing_median_age  -0.106397  0.010724            1.000000    -0.364741
# total_rooms          0.048037 -0.039724           -0.364741     1.000000
# total_bedrooms       0.073599 -0.071479           -0.322451     0.930175
# population           0.101826 -0.111689           -0.295487     0.850472
# households           0.060174 -0.076514           -0.304734     0.917415
# median_income       -0.019324 -0.074442           -0.112185     0.197129
# median_house_value  -0.046672 -0.141196            0.105935     0.135032
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.073599    0.101826    0.060174      -0.019324
# latitude                 -0.071479   -0.111689   -0.076514      -0.074442
# housing_median_age       -0.322451   -0.295487   -0.304734      -0.112185
# total_rooms               0.930175    0.850472    0.917415       0.197129
# total_bedrooms            1.000000    0.869731    0.978356      -0.009589
# population                0.869731    1.000000    0.901312       0.003183
# households                0.978356    0.901312    1.000000       0.011744
# median_income            -0.009589    0.003183    0.011744       1.000000
# median_house_value        0.051831   -0.025623    0.067149       0.686301
#
#                     median_house_value
# longitude                    -0.046672
# latitude                     -0.141196
# housing_median_age            0.105935
# total_rooms                   0.135032
# total_bedrooms                0.051831
# population                   -0.025623
# households                    0.067149
# median_income                 0.686301
# median_house_value            1.000000

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data_train.corr(), annot=True, cmap="YlGnBu")
# Out:
# <ipython-input-38-baf6ee7c0445>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_train.corr(), annot=True, cmap="YlGnBu")
# <Axes: >

# %%
data_train['total_rooms'] = np.log(data_train['total_rooms'] + 1)
data_train['total_bedrooms'] = np.log(data_train['total_bedrooms'] + 1)
data_train['population'] = np.log(data_train['population'] + 1)
data_train['households'] = np.log(data_train['households'] + 1)

# %%
data_train.hist(figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
data_train.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     7264
# INLAND        5148
# NEAR OCEAN    2142
# NEAR BAY      1788
# ISLAND           4
# Name: ocean_proximity, dtype: int64

# %%
data_train = data_train.join(pd.get_dummies(data_train.ocean_proximity)).drop(["ocean_proximity"], axis=1)

# %%
data_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3637     -118.44     34.23                36.0     7.456455        5.961005
# 19727    -121.47     38.95                34.0     7.663877        5.860786
# 9079     -118.28     34.76                19.0     8.140607        6.400257
# 18568    -121.75     36.92                48.0     7.496652        5.869297
# 10445    -117.60     33.43                21.0     8.281977        6.333280
# ...          ...       ...                 ...          ...             ...
# 2150     -119.78     36.77                45.0     7.182352        5.549076
# 15898    -122.39     37.72                52.0     4.912655        3.555348
# 5552     -118.38     33.95                29.0     7.507690        6.378426
# 17457    -120.44     34.68                 6.0     7.690743        5.627621
# 9414     -122.49     37.86                35.0     7.912057        6.289716
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 3637     7.003065    5.869297         4.0368            183100.0          1
# 19727    6.877296    5.752573         2.7039            106300.0          0
# 9079     7.505492    6.349139         4.7875            163600.0          0
# 18568    6.977281    5.891644         3.6000            194500.0          1
# 10445    7.239215    6.298949         5.1439            414000.0          0
# ...           ...         ...            ...                 ...        ...
# 2150     6.502790    5.484797         2.3562             58100.0          0
# 15898    4.543295    3.295837         2.1484            181300.0          0
# 5552     7.242798    6.261492         2.5833            187500.0          1
# 17457    6.548219    5.613128         6.2685            307400.0          0
# 9414     6.877296    6.270988         6.7669            500001.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 3637        0       0         0           0
# 19727       1       0         0           0
# 9079        1       0         0           0
# 18568       0       0         0           0
# 10445       0       0         0           1
# ...       ...     ...       ...         ...
# 2150        1       0         0           0
# 15898       0       0         1           0
# 5552        0       0         0           0
# 17457       0       0         0           1
# 9414        0       0         1           0
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data_train.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='latitude', y="longitude", data=data_train, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
data_train["badroom_ratio"] = data_train['total_bedrooms'] / data_train['total_rooms']
data_train["household_rooms"] = data_train['total_rooms'] / data_train['households']

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data_train.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

X_train, y_train = data_train.drop(['median_house_value'], axis=1), data_train['median_house_value']

lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
data_test = X_test.join(y_test)

data_test['total_rooms'] = np.log(data_test['total_rooms'] + 1)
data_test['total_bedrooms'] = np.log(data_test['total_bedrooms'] + 1)
data_test['population'] = np.log(data_test['population'] + 1)
data_test['households'] = np.log(data_test['households'] + 1)

data_test = data_test.join(pd.get_dummies(data_test.ocean_proximity)).drop(["ocean_proximity"], axis=1)

data_test["badroom_ratio"] = data_test['total_bedrooms'] / data_test['total_rooms']
data_test["household_rooms"] = data_test['total_rooms'] / data_test['households']

X_test, y_test = data_test.drop(['median_house_value'], axis=1), data_test['median_house_value']

# %%
lin_reg.score(X_test, y_test)
# Out:
# 0.6814168116405117

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaler = scaler.fit_transform(X_train)
lin_reg.fit(X_train_scaler, y_train)
# Out:
# LinearRegression()

# %%
X_test_scaler = scaler.transform(X_test)
lin_reg.score(X_test_scaler, y_test)
# Out:
# 0.6814168116405117

# %%
from sklearn.ensemble import RandomForestRegressor

rnd_reg = RandomForestRegressor()
rnd_reg.fit(X_train_scaler, y_train)
# Out:
# RandomForestRegressor()

# %%
rnd_reg.score(X_test_scaler, y_test)
# Out:
# 0.8105009718904362

# %%
from sklearn.model_selection import GridSearchCV

rnd_reg = RandomForestRegressor()

params_grid = {
    "n_estimators": [100 , 200, 300],
    "min_samples_split": [3, 4, 6, 8],
    "max_depth": [None, 4, 8, 16]
}

grid_sch = GridSearchCV(rnd_reg, params_grid,
                        cv=5, scoring='neg_mean_squared_error',
                        return_train_score=True)
grid_sch.fit(X_train_scaler, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8, 16],
#                          'min_samples_split': [3, 4, 6, 8],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_score = grid_sch.best_estimator_

# %%
best_score.score(X_test_scaler, y_test)
# Out:
# 0.8129228293668045
